# %% [markdown]
# # MACE-MDP Dipoles and Polarizability Tutorial
#
# This notebook demonstrates dipole and polarizability predictions with the **MACE-MDP** model on the first structure in the example XYZ.

# %% [markdown]
# ## Scientific context
#
# - Dipole moment is the first derivative of energy with respect to electric field:
#   $$\mu_i = -\frac{\partial E}{\partial F_i}$$
# - Polarizability is the field derivative of dipole (equivalently second field derivative of energy):
#   $$\alpha_{ij}=\frac{\partial \mu_i}{\partial F_j}=-\frac{\partial^2 E}{\partial F_i\partial F_j}$$
#
# Connection to spectroscopy:
# - IR intensity is controlled by normal-mode dipole derivatives $\partial\boldsymbol\mu/\partial Q_k$.
# - Raman activity is controlled by normal-mode polarizability derivatives $\partial\boldsymbol\alpha/\partial Q_k$.
#
# This notebook evaluates $\boldsymbol\mu$ and $\boldsymbol\alpha$ directly, then estimates simple coordinate derivatives by finite differences.

# %%
from pathlib import Path
import numpy as np

from ase.io import read
from mace.calculators.mace import MACECalculator
# Out:
# /work/mace_alpha_venv/lib/python3.11/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# Error while loading libcue_ops.so: libcuda.so.1: cannot open shared object file: No such file or directory

# %% [markdown]
# ## Paths and setup
#
# This tutorial uses the MACE-MDP model at `../models/MACE-MDP.model` relative to `examples/`.

# %%
cwd = Path.cwd().resolve()
examples_dir = cwd if cwd.name == "examples" else cwd.parent

xyz_path = examples_dir / "mini_database_IR-R-7193_wB97MD3.xyz"
model_path = examples_dir / ".." / "models" / "MACE-MDP.model"  # requested path

atoms = read(xyz_path, index=0)
print(f"Using structure with {len(atoms)} atoms")
print(f"Model path: {model_path}")
# Out:
# Using structure with 14 atoms
# Model path: /work/MACE-MDP/examples/../models/MACE-MDP.model

# %% [markdown]
# ## Evaluate dipole and polarizability

# %%
device = "cpu"  # switch to "cuda" if available

calc = MACECalculator(
    model_paths=str(model_path),
    model_type="DipolePolarizabilityMACE",
    default_dtype="float64",
    device=device,
)

mu = calc.get_property("dipole", atoms)
alpha = calc.get_property("polarizability", atoms)

print("Dipole vector:")
print(mu)
print("\nPolarizability tensor:")
print(alpha)
# Out:
# /work/mace_tensors/mace/calculators/mace.py:197: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   torch.load(f=model_path, map_location=device)
# Using head Default out of ['Default']
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[8], line 10
#       1 device = "cpu"  # switch to "cuda" if available
#       3 calc = MACECalculator(
#       4     model_paths=str(model_path),
#       5     model_type="DipoleMACE",
#       6     default_dtype="float64",
#       7     device=device,
#       8 )
# ---> 10 mu = calc.get_property("dipole", atoms)
#      11 alpha = calc.get_property("polarizability", atoms)
#      13 print("Dipole vector:")
#
# File /work/mace_alpha_venv/lib/python3.11/site-packages/ase/calculators/calculator.py:519, in BaseCalculator.get_property(self, name, atoms, allow_calculation)
#     516     if self.use_cache:
#     517         self.atoms = atoms.copy()
# --> 519     self.calculate(atoms, [name], system_changes)
#     521 if name not in self.results:
#     522     # For some reason the calculator was not able to do what we want,
#     523     # and that is OK.
#     524     raise PropertyNotImplementedError(
#     525         '{} not present in this ' 'calculation'.format(name)
#     526     )
#
# File /work/mace_tensors/mace/calculators/mace.py:401, in MACECalculator.calculate(self, atoms, properties, system_changes)
#     398 # call to base-class to set atoms attribute
#     399 Calculator.calculate(self, atoms)
# --> 401 batch_base = self._atoms_to_batch(atoms)
#     403 if self.model_type in ["MACE", "EnergyDipoleMACE"]:
#     404     batch = self._clone_batch(batch_base)
#
# File /work/mace_tensors/mace/calculators/mace.py:368, in MACECalculator._atoms_to_batch(self, atoms)
#     360 keyspec = data.KeySpecification(
#     361     info_keys=self.info_keys, arrays_keys=self.arrays_keys
#     362 )
#     363 config = data.config_from_atoms(
#     364     atoms, key_specification=keyspec, head_name=self.head
#     365 )
#     366 data_loader = torch_geometric.dataloader.DataLoader(
#     367     dataset=[
# --> 368         data.AtomicData.from_config(
#     369             config,
#     370             z_table=self.z_table,
#     371             cutoff=self.r_max,
#     372             heads=self.available_heads,
#     373         )
#     374     ],
#     375     batch_size=1,
#     376     shuffle=False,
#     377     drop_last=False,
#     378 )
#     379 batch = next(iter(data_loader)).to(self.device)
#     380 return batch
#
# File /work/mace_tensors/mace/data/atomic_data.py:336, in AtomicData.from_config(cls, config, z_table, cutoff, heads, **kwargs)
#     319 polarizability = (
#     320     torch.tensor(
#     321         config.properties.get("polarizability"), dtype=torch.get_default_dtype()
#    (...)    324     else torch.zeros(1, 3, 3, dtype=torch.get_default_dtype())
#     325 )
#     327 total_spin = (
#     328     torch.tensor(
#     329         config.properties.get("total_spin"), dtype=torch.get_default_dtype()
#    (...)    332     else torch.tensor(1.0, dtype=torch.get_default_dtype())
#     333 )
#     335 pbc = (
# --> 336     torch.tensor([config.pbc], dtype=torch.bool)
#     337     if config.pbc is not None
#     338     else torch.tensor([[False, False, False]], dtype=torch.bool)
#     339 )
#     341 return cls(
#     342     edge_index=torch.tensor(edge_index, dtype=torch.long),
#     343     positions=torch.tensor(config.positions, dtype=torch.get_default_dtype()),
#    (...)    367     pbc=pbc,
#     368 )
#
# TypeError: 'numpy.bool' object cannot be interpreted as an integer

# %% [markdown]
# ## Interpreting the output
#
# - `mu` is a 3-vector: molecular dipole components.
# - `alpha` is a 3x3 tensor: polarizability response.
